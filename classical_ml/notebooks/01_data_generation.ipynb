# %%
import sys, os
ROOT = os.path.abspath("..")   # go up one directory from notebooks/
if ROOT not in sys.path:
    sys.path.append(ROOT)

print(ROOT)
# Out:
# c:\Users\Public\workspace\sh-wave-ml-surrogate\classical_ml

# %%
# Load the provided Excel dataset instead of generating synthetic samples
import os
import pandas as pd
ROOT = os.path.abspath("..")
data_path = os.path.join(ROOT, 'data', 'raw', 'dispersion_vs_L.xlsx')
if not os.path.exists(data_path):
    data_path = os.path.join(ROOT, 'data', 'dispersion_vs_L.xlsx')
    if not os.path.exists(data_path):
        raise FileNotFoundError(f'Data file not found: {data_path}')
data = pd.read_excel(data_path)
# Show available columns and a preview
print('Data shape:', data.shape)
data.head()
# Out:
# Data shape: (870, 3)
#          kL    c_beta  L
# 0  0.099683  1.450000  1
# 1  0.100069  1.447067  1
# 2  0.100457  1.444133  1
# 3  0.100847  1.441200  1
# 4  0.100933  1.440554  1
