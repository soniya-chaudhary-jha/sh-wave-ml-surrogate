# %%
import sys, os
ROOT = os.path.abspath("..")   # go up one directory from notebooks/
if ROOT not in sys.path:
    sys.path.append(ROOT)

print(ROOT)
# Out:
# c:\Users\Public\workspace\sh-wave-ml-surrogate

# %%
from physics.parameter_sampler import sample_parameters
from physics.dispersion_solver import solve_phase_velocity
import numpy as np

X = sample_parameters(n_samples=2000)

y = np.array([solve_phase_velocity(*row) for row in X])

X[:5], y[:5]
# Out:
# (array([[ 0.11106095,  3.37621052,  0.83419952, 13.61788507],
#         [ 2.51629171,  2.37225087,  1.56229445,  7.11883978],
#         [ 2.39206792,  0.6180119 ,  0.60514911, 13.8377852 ],
#         [ 0.11347681,  2.32718127,  1.29409146,  0.73878948],
#         [ 0.29130873,  1.04424052,  1.90642372,  9.39993479]]),
#  array([ 7807.010904  ,  3595.1268477 ,  3491.30299924, 10172.9065633 ,
#          9424.34019777]))
